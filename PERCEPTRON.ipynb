# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/placement (1).csv')
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(x ='cgpa',y ='resume_score',data=df)
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
x=df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_ # THESE ARE THE WEIGHTS
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_ # THE BIAS
# Out:
# array([-25.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.values,y.values,clf=p,legend=2)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %% [markdown]
# # HOW TO TRAIN A PERCEPTRON

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=41,hypercube=False,class_sep=10)
print(X.shape)
print(y.shape)
# WE CAN GENEREATE OUR OWN DATASET BY USING make_classification FOR CLASSIFICATION PURPOSE .SIMILARY make_regression CAN ALSO BE USED
# Out:
# (100, 2)
# (100,)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
def step(z):
  return 1 if z>0 else 0

# %%
def Perceptron(x,y):
  X = np.insert(x,0,1,axis=1) # THIS CONVERTS [ 0.3334],1,34443] into [1,0.3334, 1.34443] i.e adds 1 to front
  weights = np.ones(X.shape[1]) # 1 means column. this will create an array of ones with the shape of column of X
  learning_rate = 0.1
  for i in range(1000):
    j = np.random.randint(0,100) # THE RANDOM NUMBER WILL BE THE POINT WHICH WILL BE SELECTED BY PERCEPTRON
    y_predicted = step(np.dot(X[j],weights))
    weights = weights + learning_rate*(y[j]-y_predicted)*X[j]
  return weights[0],weights[1:] # WEIGHTS[0] MEANS INTERCEPT TERM wo

# %%
intercept_,coef_ = Perceptron(X,y)

# %%
print(coef_)
print(intercept_)
# Out:
# [1.36005507 0.06745892]
# 1.0

# %%
# EQUATION Ax+By+C =0
m = -coef_[0]/coef_[1] # m = -A/B. HERE COEFFICIENT HAS 2 VALUES [w0,w1] i.e A,B
c = -intercept_/coef_[1] # c = -C/B

# %%
def Perceptron(X,y):
  w1=w2=b=1
  lr = 0.1
  for j in range(1000):
    for i in range(X.shape[0]):
      z = w1*X[i][0] + w2*X[i][1] + b
    if z*y[i] < 0:
      w1 = w1 +lr*y[i]*X[i][0]
      w2 = w2 + lr*y[i]*X[i][1]
      b = b + lr*y[i]
  return w1,w1,b

# %%
w1,w2,b = Perceptron(X,y)
b
# Out:
# 1
